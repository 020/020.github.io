# %% [markdown]
# <a href="https://colab.research.google.com/github/020/020.github.io/blob/master/pycaret_ts_alpha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret-ts-alpha
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 468 kB 7.6 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 45.7 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 47.9 MB/s
# ...
#      |████████████████████████████████| 79.9 MB 122 kB/s
# ...
#      |████████████████████████████████| 2.0 MB 45.0 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.1 MB/s
# ...
#      |████████████████████████████████| 69 kB 8.8 MB/s
# ...
#      |████████████████████████████████| 303 kB 55.2 MB/s
# ...
#      |████████████████████████████████| 9.8 MB 45.9 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 40.1 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 21.8 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 120 kB 61.6 MB/s
# ...
#      |████████████████████████████████| 930 kB 12.2 MB/s
# ...
#      |████████████████████████████████| 34.5 MB 5.3 kB/s
# ...

# %%
import pandas as pd
from pycaret.datasets import get_data
data = get_data('pycaret_downloads')
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True, drop=True)
data = data.asfreq('D')
# Out:
#         Date  Total
# 0   7/8/2021   3773
# 1   7/9/2021   3172
# 2  7/10/2021   2079
# 3  7/11/2021   2725
# 4  7/12/2021   4542

# %%
from pycaret.time_series import *
setup(data, fh = 7, fold = 5, session_id = 123)
# Out:
#                     Description                    Value
# 0                    session_id                      123
# 1                 Original Data                  (90, 1)
# 2                Missing Values                    False
# 3         Transformed Train Set                    (83,)
# 4          Transformed Test Set                     (7,)
# 5                Fold Generator  ExpandingWindowSplitter
# 6                   Fold Number                        5
# 7   Enforce Prediction Interval                    False
# 8        Seasonal Period Tested                        7
# 9          Seasonality Detected                     True
# 10     Target Strictly Positive                     True
# 11           Target White Noise                       No
# 12                Recommended d                        1
# 13       Recommended Seasonal D                        1
# 14                     CPU Jobs                       -1
# ...

# %%
check_stats()
# Out:
#             Test   Test Name  ...                   Setting        Value
# 0        Summary  Statistics  ...                                     90
# 1        Summary  Statistics  ...                                4960.37
# 2        Summary  Statistics  ...                                 4776.5
# 3        Summary  Statistics  ...                                   1939
# 4        Summary  Statistics  ...                            3.75972e+06
# 5        Summary  Statistics  ...                              -0.920113
# 6        Summary  Statistics  ...                                0.22622
# 7        Summary  Statistics  ...                                     89
# 8    White Noise   Ljung-Box  ...  {'alpha': 0.05, 'K': 24}      293.089
# 9    White Noise   Ljung-Box  ...  {'alpha': 0.05, 'K': 48}      460.126
# 10   White Noise   Ljung-Box  ...  {'alpha': 0.05, 'K': 24}  4.11726e-48
# 11   White Noise   Ljung-Box  ...  {'alpha': 0.05, 'K': 48}  1.09758e-68
# ...

# %%
plot_model(plot = 'ts')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(plot = 'train_test_split')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(plot = 'cv')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(plot = 'acf')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(plot = 'pacf')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(plot = 'diagnostics')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(plot = 'decomp_stl')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
best = compare_models()
# Out:
#                                                              Model      MAE  \
# arima                                                        ARIMA  592.309
# et_cds_dt          Extra Trees w/ Cond. Deseasonalize & Detrending  587.636
# auto_arima                                              Auto ARIMA  568.373
# omp_cds_dt       Orthogonal Matching Pursuit w/ Cond. Deseasona...  618.617
# ada_cds_dt            AdaBoost w/ Cond. Deseasonalize & Detrending  601.205
# rf_cds_dt        Random Forest w/ Cond. Deseasonalize & Detrending  618.624
# gbr_cds_dt       Gradient Boosting w/ Cond. Deseasonalize & Det...  667.554
# theta                                             Theta Forecaster   630.24
# snaive                                   Seasonal Naive Forecaster  678.743
# br_cds_dt        Bayesian Ridge w/ Cond. Deseasonalize & Detren...  695.175
# exp_smooth                                   Exponential Smoothing   665.56
# ...

# %%
plot_model(best, plot = 'forecast')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(finalize_model(best), plot = 'forecast', data_kwargs = {'fh' : 24})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(best, plot = 'residuals')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(best, plot = 'diagnostics')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
predict_model(best, fh = 300)
# Out:
# 2021-09-29     8992.0128
# 2021-09-30     8713.4148
# 2021-10-01     7543.2666
# 2021-10-02     3889.5166
# 2021-10-03     4395.9383
#                  ...
# 2022-07-21    21127.5644
# 2022-07-22    19957.1173
# 2022-07-23    16303.2301
# 2022-07-24    16809.5888
# 2022-07-25    20132.8662
# Freq: D, Name: Total, Length: 300, dtype: float64

# %%
#Arrivals
import pandas as pd
data = pd.read_csv('/content/emergency_arrivals_date_ISO_no_covid.csv')
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True, drop=True)
data = data.asfreq('M')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 216 entries, 2002-01-31 to 2019-12-31
# Freq: M
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Arrivals  216 non-null    int64
# dtypes: int64(1)
# memory usage: 3.4 KB

# %%
data.head(12)
# Out:
#             Arrivals
# Date
# 2002-01-31     47627
# 2002-02-28     41944
# 2002-03-31     50137
# 2002-04-30     47394
# 2002-05-31     48566
# 2002-06-30     49923
# 2002-07-31     51652
# 2002-08-31     52224
# 2002-09-30     49559
# 2002-10-31     48250
# 2002-11-30     49189
# 2002-12-31     51997

# %%
from pycaret.time_series import *
setup(data, fh = 7, fold = 5, session_id = 123)
# Out:
#                     Description                    Value
# 0                    session_id                      123
# 1                        Target                 Arrivals
# 2                      Approach               Univariate
# 3           Exogenous Variables              Not Present
# 4                    Data shape                 (216, 1)
# 5              Train data shape                 (209, 1)
# 6               Test data shape                   (7, 1)
# 7                Fold Generator  ExpandingWindowSplitter
# 8                   Fold Number                        5
# 9   Enforce Prediction Interval                    False
# 10    Seasonal Period(s) Tested                       12
# 11          Seasonality Present                     True
# 12       Seasonalities Detected                     [12]
# 13          Primary Seasonality                       12
# 14     Target Strictly Positive                     True
# ...

# %%
check_stats()
# Out:
#             Test   Test Name    Data             Property  \
# 0        Summary  Statistics  Actual               Length
# 1        Summary  Statistics  Actual                 Mean
# 2        Summary  Statistics  Actual               Median
# 3        Summary  Statistics  Actual   Standard Deviation
# 4        Summary  Statistics  Actual             Variance
# 5        Summary  Statistics  Actual             Kurtosis
# 6        Summary  Statistics  Actual             Skewness
# 7        Summary  Statistics  Actual    # Distinct Values
# 8    White Noise   Ljung-Box  Actual       Test Statictic
# 9    White Noise   Ljung-Box  Actual       Test Statictic
# 10   White Noise   Ljung-Box  Actual              p-value
# 11   White Noise   Ljung-Box  Actual              p-value
# 12   White Noise   Ljung-Box  Actual          White Noise
# 13   White Noise   Ljung-Box  Actual          White Noise
# 14  Stationarity         ADF  Actual         Stationarity
# ...

# %%
plot_model(plot = 'ts')

# %%
plot_model(plot = 'train_test_split')

# %%
plot_model(plot = 'diagnostics')

# %%
plot_model(plot = 'decomp_stl')

# %%
best = compare_models()
# Out:
#                                                              Model  \
# auto_arima                                              Auto ARIMA
# arima                                                        ARIMA
# huber_cds_dt             Huber w/ Cond. Deseasonalize & Detrending
# rf_cds_dt        Random Forest w/ Cond. Deseasonalize & Detrending
# snaive                                   Seasonal Naive Forecaster
# lightgbm_cds_dt  Light Gradient Boosting w/ Cond. Deseasonalize...
# ets                                                            ETS
# ada_cds_dt            AdaBoost w/ Cond. Deseasonalize & Detrending
# en_cds_dt          Elastic Net w/ Cond. Deseasonalize & Detrending
# ridge_cds_dt             Ridge w/ Cond. Deseasonalize & Detrending
# lr_cds_dt               Linear w/ Cond. Deseasonalize & Detrending
# lar_cds_dt       Least Angular Regressor w/ Cond. Deseasonalize...
# lasso_cds_dt             Lasso w/ Cond. Deseasonalize & Detrending
# ...

# %%
plot_model(best, plot = 'forecast')

# %%
plot_model(finalize_model(best), plot = 'forecast', data_kwargs = {'fh' : 24})

# %%
plot_model(best, plot = 'residuals')

# %%
plot_model(best, plot = 'diagnostics')

# %%
predict_model(best, fh = 50)
# Out:
#               y_pred
# 2019-06   92465.5151
# 2019-07   93432.2057
# 2019-08   96771.3382
# 2019-09   94642.4423
# 2019-10   94805.8856
# 2019-11   94124.7768
# 2019-12   96212.5044
# 2020-01   95197.7832
# 2020-02   90132.9412
# 2020-03   96616.7181
# 2020-04   93254.6731
# 2020-05   94344.4633
# 2020-06   93540.0501
# 2020-07   94632.6855
# 2020-08   97683.9773
# 2020-09   96055.0070
# 2020-10   96360.8113
# 2020-11   95383.0059
# 2020-12   97895.7600
# 2021-01   96462.5036
# 2021-02   91422.6411
# 2021-03   98125.0282
# 2021-04   94840.9543
# 2021-05   96705.6874
# 2021-06   95773.0542
# 2021-07   96766.1776
# 2021-08   99657.4034
# 2021-09   98051.2841
# 2021-10   98310.3916
# 2021-11   97460.6404
# 2021-12   99716.0464
# 2022-01   98466.3934
# 2022-02   93782.1901
# 2022-03   99968.6352
# 2022-04   96905.3208
# 2022-05   98492.2303
# 2022-06   97652.4002
# 2022-07   98595.9617
# 2022-08  101314.2018
# 2022-09   99820.0354
# 2022-10  100071.7196
# 2022-11   99260.1429
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)
