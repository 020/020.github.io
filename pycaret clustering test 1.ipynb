# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('/users/he145100/ED_Adm_less_rows_100k.csv')

# %%
data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (94999, 23)
# Unseen Data For Predictions: (5000, 23)

# %%
from pycaret.clustering import *

exp_clu101 = setup(data, normalize = True, 
                   session_id = 123)
# Out:
# <style type="text/css">
# #T_1098c_row21_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1098c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1098c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1098c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1098c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1098c_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_1098c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1098c_row1_col0" class="data row1 col0" >Original Data</td>
#       <td id="T_1098c_row1_col1" class="data row1 col1" >(94999, 23)</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1098c_row2_col0" class="data row2 col0" >Missing Values</td>
#       <td id="T_1098c_row2_col1" class="data row2 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1098c_row3_col0" class="data row3 col0" >Numeric Features</td>
#       <td id="T_1098c_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1098c_row4_col0" class="data row4 col0" >Categorical Features</td>
#       <td id="T_1098c_row4_col1" class="data row4 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1098c_row5_col0" class="data row5 col0" >Ordinal Features</td>
#       <td id="T_1098c_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1098c_row6_col0" class="data row6 col0" >High Cardinality Features</td>
#       <td id="T_1098c_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1098c_row7_col0" class="data row7 col0" >High Cardinality Method</td>
#       <td id="T_1098c_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1098c_row8_col0" class="data row8 col0" >Transformed Data</td>
#       <td id="T_1098c_row8_col1" class="data row8 col1" >(94999, 8476)</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1098c_row9_col0" class="data row9 col0" >CPU Jobs</td>
#       <td id="T_1098c_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1098c_row10_col0" class="data row10 col0" >Use GPU</td>
#       <td id="T_1098c_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1098c_row11_col0" class="data row11 col0" >Log Experiment</td>
#       <td id="T_1098c_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1098c_row12_col0" class="data row12 col0" >Experiment Name</td>
#       <td id="T_1098c_row12_col1" class="data row12 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1098c_row13_col0" class="data row13 col0" >USI</td>
#       <td id="T_1098c_row13_col1" class="data row13 col1" >1397</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1098c_row14_col0" class="data row14 col0" >Imputation Type</td>
#       <td id="T_1098c_row14_col1" class="data row14 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1098c_row15_col0" class="data row15 col0" >Iterative Imputation Iteration</td>
#       <td id="T_1098c_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1098c_row16_col0" class="data row16 col0" >Numeric Imputer</td>
#       <td id="T_1098c_row16_col1" class="data row16 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1098c_row17_col0" class="data row17 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_1098c_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1098c_row18_col0" class="data row18 col0" >Categorical Imputer</td>
#       <td id="T_1098c_row18_col1" class="data row18 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1098c_row19_col0" class="data row19 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_1098c_row19_col1" class="data row19 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1098c_row20_col0" class="data row20 col0" >Unknown Categoricals Handling</td>
#       <td id="T_1098c_row20_col1" class="data row20 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_1098c_row21_col0" class="data row21 col0" >Normalize</td>
#       <td id="T_1098c_row21_col1" class="data row21 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_1098c_row22_col0" class="data row22 col0" >Normalize Method</td>
#       <td id="T_1098c_row22_col1" class="data row22 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_1098c_row23_col0" class="data row23 col0" >Transformation</td>
#       <td id="T_1098c_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_1098c_row24_col0" class="data row24 col0" >Transformation Method</td>
#       <td id="T_1098c_row24_col1" class="data row24 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_1098c_row25_col0" class="data row25 col0" >PCA</td>
#       <td id="T_1098c_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_1098c_row26_col0" class="data row26 col0" >PCA Method</td>
#       <td id="T_1098c_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_1098c_row27_col0" class="data row27 col0" >PCA Components</td>
#       <td id="T_1098c_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_1098c_row28_col0" class="data row28 col0" >Ignore Low Variance</td>
#       <td id="T_1098c_row28_col1" class="data row28 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_1098c_row29_col0" class="data row29 col0" >Combine Rare Levels</td>
#       <td id="T_1098c_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1098c_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_1098c_row30_col0" class="data row30 col0" >Rare Level Threshold</td>
#       <td id="T_1098c_row30_col1" class="data ro

# %%
kmeans = create_model('kmeans')
# Out:
#    Silhouette  Calinski-Harabasz  Davies-Bouldin  Homogeneity  Rand Index  \
# 0       0.041           3968.384          3.6871            0           0
#
#    Completeness
# 0             0

# %%
plot_model(kmeans, plot = 'elbow')

# %%
plot_model(kmeans, plot = 'silhouette')
